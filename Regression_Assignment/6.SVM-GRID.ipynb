# %%
import pandas as pd

# %%
dataset=pd.read_csv("insurance_pre.csv")

# %%
dataset=pd.get_dummies(dataset,dtype=int,drop_first=True)

# %%
dataset
# Out:
#       age     bmi  children      charges  sex_male  smoker_yes
# 0      19  27.900         0  16884.92400         0           1
# 1      18  33.770         1   1725.55230         1           0
# 2      28  33.000         3   4449.46200         1           0
# 3      33  22.705         0  21984.47061         1           0
# 4      32  28.880         0   3866.85520         1           0
# ...   ...     ...       ...          ...       ...         ...
# 1333   50  30.970         3  10600.54830         1           0
# 1334   18  31.920         0   2205.98080         0           0
# 1335   18  36.850         0   1629.83350         0           0
# 1336   21  25.800         0   2007.94500         0           0
# 1337   61  29.070         0  29141.36030         0           1
#
# [1338 rows x 6 columns]

# %%
independent=dataset[['age', 'bmi', 'children', 'sex_male', 'smoker_yes']]

# %%
dependent=dataset[['charges']]

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(independent, dependent, test_size=0.30,random_state=0)

# %%
from sklearn.svm import SVR
from sklearn.model_selection import GridSearchCV
param_grid = {'kernel':['rbf','sigmoid','linear'],
'C':[10,100,1000,2000,3000],'gamma':['auto','scale']}
grid=GridSearchCV(SVR(),param_grid,refit=True,verbose=3,n_jobs=-1)
grid.fit(X_train,y_train)
# Out:
# Fitting 5 folds for each of 30 candidates, totalling 150 fits
# C:\Users\SMART\anaconda3\Lib\site-packages\sklearn\utils\validation.py:1339: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# GridSearchCV(estimator=SVR(), n_jobs=-1,
#              param_grid={'C': [10, 100, 1000, 2000, 3000],
#                          'gamma': ['auto', 'scale'],
#                          'kernel': ['rbf', 'sigmoid', 'linear']},
#              verbose=3)

# %%
re=grid.cv_results_
print("The R_score value for best parameter {}:".format(grid.best_params_))
# Out:
# The R_score value for best parameter {'C': 2000, 'gamma': 'auto', 'kernel': 'linear'}:

# %%
table=pd.DataFrame.from_dict(re)

# %%
table
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  param_C  \
# 0        0.066921      0.002384         0.029057        0.000745       10
# 1        0.052569      0.002997         0.012117        0.001267       10
# 2        0.063465      0.001674         0.009504        0.000397       10
# 3        0.057422      0.002241         0.030268        0.002664       10
# 4        0.061519      0.001707         0.016525        0.001570       10
# 5        0.066835      0.003377         0.009955        0.001689       10
# 6        0.065481      0.002782         0.030288        0.001840      100
# 7        0.049494      0.001809         0.012965        0.000814      100
# 8        0.142063      0.031041         0.010804        0.001050      100
# 9        0.056869      0.001367         0.030202        0.000847      100
# 10       0.064034      0.002071         0.015363        0.000785      100
# 11       0.139279      0.030553         0.010128        0.001286      100
# 12       0.090484      0.001511         0.030206        0.001405     1000
# 13       0.049261      0.001752         0.012172        0.000497     1000
# 14       0.503067      0.052750         0.009872        0.001555     1000
# 15       0.064149      0.002425         0.031004        0.001556     1000
# 16       0.064078      0.002055         0.015823        0.000929     1000
# 17       0.509931      0.069262         0.009975        0.000687     1000
# 18       0.110095      0.006122         0.029743        0.001380     2000
# 19       0.051354      0.001772         0.012036        0.000995     2000
# 20       0.887453      0.102970         0.010589        0.001367     2000
# 21       0.071123      0.004018         0.031294        0.002281     2000
# 22       0.062785      0.001205         0.016131        0.001030     2000
# 23       0.881458      0.124716         0.011277        0.001386     2000
# 24       0.139002      0.009987         0.029996        0.000288     3000
# 25       0.051356      0.001133         0.013315        0.002030     3000
# 26       1.703960      0.820463         0.011289        0.002203     3000
# 27       0.073851      0.004248         0.030434        0.001569     3000
# 28       0.066252      0.001828         0.015802        0.000969     3000
# 29       1.742924      0.932992         0.008073        0.002114     3000
#
#    param_gamma param_kernel  \
# 0         auto          rbf
# 1         auto      sigmoid
# 2         auto       linear
# 3        scale          rbf
# 4        scale      sigmoid
# 5        scale       linear
# 6         auto          rbf
# 7         auto      sigmoid
# 8         auto       linear
# 9        scale          rbf
# 10       scale      sigmoid
# 11       scale       linear
# 12        auto          rbf
# 13        auto      sigmoid
# 14        auto       linear
# 15       scale          rbf
# 16       scale      sigmoid
# 17       scale       linear
# 18        auto          rbf
# 19        auto      sigmoid
# 20        auto       linear
# 21       scale          rbf
# 22       scale      sigmoid
# 23       scale       linear
# 24        auto          rbf
# 25        auto      sigmoid
# 26        auto       linear
# 27       scale          rbf
# 28       scale      sigmoid
# 29       scale       linear
#
#                                                params  split0_test_score  \
# 0         {'C': 10, 'gamma': 'auto', 'kernel': 'rbf'}          -0.041899
# 1     {'C': 10, 'gamma': 'auto', 'kernel': 'sigmoid'}          -0.041634
# 2      {'C': 10, 'gamma': 'auto', 'kernel': 'linear'}          -0.099849
# 3        {'C': 10, 'gamma': 'scale', 'kernel': 'rbf'}          -0.045477
# 4    {'C': 10, 'gamma': 'scale', 'kernel': 'sigmoid'}          -0.042877
# 5     {'C': 10, 'gamma': 'scale', 'kernel': 'linear'}          -0.099849
# 6        {'C': 100, 'gamma': 'auto', 'kernel': 'rbf'}          -0.040107
# 7    {'C': 100, 'gamma': 'auto', 'kernel': 'sigmoid'}          -0.041634
# 8     {'C': 100, 'gamma': 'auto', 'kernel': 'linear'}           0.477795
# 9       {'C': 100, 'gamma': 'scale', 'kernel': 'rbf'}          -0.158546
# 10  {'C': 100, 'gamma': 'scale', 'kernel': 'sigmoid'}          -0.059561
# 11   {'C': 100, 'gamma': 'scale', 'kernel': 'linear'}           0.477795
# 12      {'C': 1000, 'gamma': 'auto', 'kernel': 'rbf'}          -0.064434
# 13  {'C': 1000, 'gamma': 'auto', 'kernel': 'sigmoid'}          -0.041634
# 14   {'C': 1000, 'gamma': 'auto', 'kernel': 'linear'}           0.592288
# 15     {'C': 1000, 'gamma': 'scale', 'kernel': 'rbf'}          -0.191422
# 16  {'C': 1000, 'gamma': 'scale', 'kernel': 'sigmo...          -1.141295
# 17  {'C': 1000, 'gamma': 'scale', 'kernel': 'linear'}           0.592288
# 18      {'C': 2000, 'gamma': 'auto', 'kernel': 'rbf'}          -0.041473
# 19  {'C': 2000, 'gamma': 'auto', 'kernel': 'sigmoid'}          -0.041634
# 20   {'C': 2000, 'gamma': 'auto', 'kernel': 'linear'}           0.600340
# 21     {'C': 2000, 'gamma': 'scale', 'kernel': 'rbf'}          -0.188138
# 22  {'C': 2000, 'gamma': 'scale', 'kernel': 'sigmo...          -4.204699
# 23  {'C': 2000, 'gamma': 'scale', 'kernel': 'linear'}           0.600340
# 24      {'C': 3000, 'gamma': 'auto', 'kernel': 'rbf'}          -0.010838
# 25  {'C': 3000, 'gamma': 'auto', 'kernel': 'sigmoid'}          -0.041634
# 26   {'C': 3000, 'gamma': 'auto', 'kernel': 'linear'}           0.600282
# 27     {'C': 3000, 'gamma': 'scale', 'kernel': 'rbf'}          -0.182267
# 28  {'C': 3000, 'gamma': 'scale', 'kernel': 'sigmo...          -9.347820
# 29  {'C': 3000, 'gamma': 'scale', 'kernel': 'linear'}           0.600282
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 0           -0.035931          -0.147151          -0.139987
# 1           -0.038077          -0.148674          -0.138698
# 2            0.109498          -0.136196          -0.141381
# 3           -0.013336          -0.151791          -0.151967
# 4           -0.039512          -0.150154          -0.138492
# 5            0.109498          -0.136196          -0.141381
# 6           -0.020972          -0.140683          -0.137931
# 7           -0.038077          -0.148674          -0.138698
# 8            0.582292           0.432079           0.458983
# 9            0.013775          -0.243127          -0.254520
# 10          -0.063480          -0.155368          -0.152757
# 11           0.582292           0.432079           0.458983
# 12           0.041169          -0.173627          -0.162395
# 13          -0.038077          -0.148674          -0.138698
# 14           0.663607           0.559347           0.582636
# 15           0.021962          -0.246590          -0.264813
# 16          -1.269703          -1.074688          -1.221982
# 17           0.663607           0.559347           0.582636
# 18           0.086956          -0.143583          -0.129675
# 19          -0.038077          -0.148674          -0.138698
# 20           0.664454           0.564693           0.618692
# 21           0.029758          -0.237425          -0.256760
# 22          -4.639898          -3.600431          -4.265575
# 23           0.664454           0.564693           0.618692
# 24           0.123650          -0.111710          -0.089701
# 25          -0.038077          -0.148674          -0.138698
# 26           0.600528           0.571175           0.562946
# 27           0.038588          -0.228062          -0.245915
# 28         -10.015654          -7.896694          -9.548932
# 29           0.600528           0.571175           0.562946
#
#     split4_test_score  mean_test_score  std_test_score  rank_test_score
# 0           -0.142206        -0.101435        0.051135               16
# 1           -0.142137        -0.101844        0.050727               17
# 2           -0.075432        -0.068672        0.092313               11
# 3           -0.139448        -0.100404        0.059028               15
# 4           -0.143396        -0.102886        0.050518               22
# 5           -0.075432        -0.068672        0.092313               11
# 6           -0.133749        -0.094689        0.052772               13
# 7           -0.142137        -0.101844        0.050727               17
# 8            0.439511         0.478132        0.054459                7
# 9           -0.166782        -0.161840        0.095993               25
# 10          -0.160115        -0.118256        0.046401               23
# 11           0.439511         0.478132        0.054459                7
# 12          -0.131375        -0.098133        0.079341               14
# 13          -0.142137        -0.101844        0.050727               17
# 14           0.558849         0.591345        0.038415                3
# 15          -0.174935        -0.171160        0.102158               27
# 16          -1.154634        -1.172460        0.067464               28
# 17           0.558849         0.591345        0.038415                3
# 18          -0.106186        -0.066792        0.084478               10
# 19          -0.142137        -0.101844        0.050727               17
# 20           0.563567         0.602349        0.037550                1
# 21          -0.168701        -0.164253        0.102120               26
# 22          -3.612375        -4.064596        0.402727               29
# 23           0.563567         0.602349        0.037550                1
# 24          -0.074932        -0.032706        0.085086                9
# 25          -0.142137        -0.101844        0.050727               17
# 26           0.565766         0.580139        0.016757                5
# 27          -0.161880        -0.155907        0.101849               24
# 28          -7.664412        -8.894703        0.938030               30
# 29           0.565766         0.580139        0.016757                5

# %%
grid.best_score_
# Out:
# 0.602348976035886

# %%
age=float(input('Age:'))
bmi_input=float(input('BMI:'))
childeren=float(input('childeren:'))
sex=int(input('sex Male=0 or else'))
smoker=int(input('smoker Yes=0 else 1'))
# Out:
# Age: 32
# BMI: 43
# childeren: 2
# sex Male=0 or else 0
# smoker Yes=0 else 1 1

# %%
Future_predict=grid.predict([[age,bmi_input,childeren,sex,smoker]])
# Out:
# C:\Users\SMART\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but SVR was fitted with feature names
#   warnings.warn(

# %%
Future_predict
# Out:
# array([24661.56480573])
